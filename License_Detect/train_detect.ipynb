# %%
from ultralytics import YOLO

# โหลด pretrained model (เล็ก เหมาะกับ 4GB VRAM)
model = YOLO("yolov8n.pt")

# เริ่ม train
model.train(
    data="data.yaml",   # path ไปไฟล์ data.yaml
    epochs=30,
    imgsz=512,          # เพราะ dataset resize 512x512
    batch=8,            # ถ้า VRAM เต็ม ลดเป็น 4
    device=0,           # ใช้ GPU
    workers=4,
    project="runs",
    name="plate_train"
)
# Out:
# Ultralytics 8.4.14  Python-3.11.4 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("vehicle_plate.pt")
print(model.names)

results = model("motor2.jpg", save=True)
# Out:
# {0: 'Car-license-plate', 1: 'Motorcycle-license-plate'}
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C3k2(
#       (cv1): Conv(
#         (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
from ultralytics import YOLO
import cv2

# โหลดโมเดล detect ป้าย
model = YOLO("vehicle_plate.pt")

cap = cv2.VideoCapture(0)  # 0 = กล้องหลัก
y = 0
while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)[0]


    for box in results.boxes:
        y = y + 1
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        conf = float(box.conf[0])
        cls_id = int(box.cls[0])
        class_name = model.names[cls_id]

        # วาดกรอบ
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 2)

        # แสดง confidence
        label = f"{class_name} {conf:.2f}"
        cv2.putText(frame, label, (x1, y1-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0), 2)
    cv2.imshow("License Plate Detection", frame)

    # กด q เพื่อออก
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 57.9ms
# Speed: 2.9ms preprocess, 57.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 47.3ms
# Speed: 3.5ms preprocess, 47.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 47.2ms
# Speed: 3.2ms preprocess, 47.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 43.4ms
# Speed: 3.1ms preprocess, 43.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 10.1ms
# Speed: 1.2ms preprocess, 10.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.3ms
# Speed: 1.1ms preprocess, 8.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 6.8ms
# ...
